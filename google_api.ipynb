rtXNWYYS-V_CjJmVwICX-1JslQyCVOsY31ZIV9eG1CMT5v; __Secure-1PSIDCC=AKEyXzU4oMOEk2GO7bCQP3AB8M98ZIFvuOONewoQkTL32SQVOpmD8JO5pWEMOf-XFvyFnXB593KV; __Secure-3PSIDCC=AKEyXzUwUCXEgPN8IF5OcBrCwfMMny52n3LVlpBXQUEiGzSzr65o_0BYlmn4SinuuIl5aJijTA9X',
}

params = {
    'rpcids': 'pONvgf',
    'source-path': '/',
    'f.sid': '5297812027339143999',
    'bl': 'boq_apps-edu-classroom-ui_20250521.05_p0',
    'hl': 'vi',
    'soc-app': '1',
    'soc-platform': '1',
    'soc-device': '1',
    '_reqid': '658538',
    'rt': 'c',
}

data = 'f.req=%5B%5B%5B%22pONvgf%22%2C%22%5B%5B3%2Cnull%2C1%2C0%5D%2C%5B%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5Bnull%2C1%5D%2Cnull%2C%5B1%2C1%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5B1%5D%5D%2Cnull%2Cnull%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%5D%2C%5B%5Bnull%2C%5B%5B%5C%22701645243921%5C%22%5D%5D%2C%5B2%2C5%5D%2C%5B2%5D%2Cnull%2C%5B%5B1748624400000%2C1749229200000%5D%5D%5D%5D%5D%22%2Cnull%2C%22generic%22%5D%5D%5D&at=ACSV3vxsjwZSgiAryAxfbd52pbLj%3A1748682938584&'

response = requests.post(
    'https://classroom.google.com/_/ClassroomUi/data/batchexecute',
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %%
import json
import re
response_text = response.text
lines = response_text.strip().splitlines()

# Get the 4th line (index 3)
target_line = lines[3]
print("Target Line:", target_line)

# new_response = response.strip()
# matches = re.findall(r'\[\[.*?\]\]', new_response, re.DOTALL)

# if matches:
#     first_json_array = matches[0]
    
#     try:
#         parsed = json.loads(first_json_array)
#         print("Parsed JSON:", parsed)
#     except json.JSONDecodeError as e:
#         print("JSON parsing error:", e)
# else:
#     print("No valid JSON array found")
# Out:
# Target Line: [["wrb.fr","pONvgf",null,null,null,[7],"generic"],["di",101],["af.httprm",100,"7022667624777356607",23]]

# %% [markdown]
# # 12A1

# %%
import requests

cookies = {
    'HSID': 'AL5aAepmh94qAPFwy',
    'SSID': 'Ang8brV8y_xhFr80z',
    'APISID': 'MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e',
    'SAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-1PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-3PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-ENID': '25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A',
    'SID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076',
    '__Secure-1PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076',
    '__Secure-3PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076',
    'SEARCH_SAMESITE': 'CgQIjZ4B',
    'AEC': 'AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g',
    'NID': '524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go',
    '__Secure-1PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    '__Secure-3PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    'OTZ': '8106180_28_28__28_',
    'SIDCC': 'AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5',
    '__Secure-1PSIDCC': 'AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx',
    '__Secure-3PSIDCC': 'AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7',
    'content-type': 'application/x-www-form-urlencoded;charset=UTF-8',
    'origin': 'https://classroom.google.com',
    'priority': 'u=1, i',
    'referer': 'https://classroom.google.com/',
    'sec-ch-ua': '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-form-factors': '"Desktop"',
    'sec-ch-ua-full-version': '"136.0.7103.114"',
    'sec-ch-ua-full-version-list': '"Chromium";v="136.0.7103.114", "Google Chrome";v="136.0.7103.114", "Not.A/Brand";v="99.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"19.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36',
    'x-client-data': 'CIm2yQEIorbJAQipncoBCOfvygEIk6HLAQiSo8sBCIWgzQEI/tPOAQiK7c4BCJDxzgEIkPLOAQi88s4BGODizgE=',
    'x-goog-ext-53200201-jspb': '[{"444624357":[701642944754]}]',
    'x-same-domain': '1',
    # 'cookie': 'HSID=AL5aAepmh94qAPFwy; SSID=Ang8brV8y_xhFr80z; APISID=MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e; SAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-1PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-3PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-ENID=25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A; SID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076; __Secure-1PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076; __Secure-3PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076; SEARCH_SAMESITE=CgQIjZ4B; AEC=AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g; NID=524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go; __Secure-1PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; __Secure-3PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; OTZ=8106180_28_28__28_; SIDCC=AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5; __Secure-1PSIDCC=AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx; __Secure-3PSIDCC=AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

params = {
    'rpcids': 'pONvgf',
    'source-path': '/',
    'f.sid': '5429727544357922217',
    'bl': 'boq_apps-edu-classroom-ui_20250521.05_p0',
    'hl': 'vi',
    'soc-app': '1',
    'soc-platform': '1',
    'soc-device': '1',
    '_reqid': '750451',
    'rt': 'c',
}

data = 'f.req=%5B%5B%5B%22pONvgf%22%2C%22%5B%5B3%2Cnull%2C1%2C0%5D%2C%5B%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5Bnull%2C1%5D%2Cnull%2C%5B1%2C1%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5B1%5D%5D%2Cnull%2Cnull%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%5D%2C%5B%5Bnull%2C%5B%5B%5C%22701642944754%5C%22%5D%5D%2C%5B2%2C5%5D%2C%5B2%5D%2Cnull%2C%5B%5B1748624400000%2C1749229200000%5D%5D%5D%5D%5D%22%2Cnull%2C%22generic%22%5D%5D%5D&at=ACSV3vzxjs3eZjqlQT1FKTRf800z%3A1748674850742&'

response = requests.post(
    'https://classroom.google.com/_/ClassroomUi/data/batchexecute',
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %% [markdown]
# # 11A

# %%
import requests

cookies = {
    'HSID': 'AL5aAepmh94qAPFwy',
    'SSID': 'Ang8brV8y_xhFr80z',
    'APISID': 'MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e',
    'SAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-1PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-3PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-ENID': '25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A',
    'SID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076',
    '__Secure-1PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076',
    '__Secure-3PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076',
    'SEARCH_SAMESITE': 'CgQIjZ4B',
    'AEC': 'AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g',
    'NID': '524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go',
    '__Secure-1PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    '__Secure-3PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    'OTZ': '8106180_28_28__28_',
    'SIDCC': 'AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5',
    '__Secure-1PSIDCC': 'AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx',
    '__Secure-3PSIDCC': 'AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7',
    'content-type': 'application/x-www-form-urlencoded;charset=UTF-8',
    'origin': 'https://classroom.google.com',
    'priority': 'u=1, i',
    'referer': 'https://classroom.google.com/',
    'sec-ch-ua': '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-form-factors': '"Desktop"',
    'sec-ch-ua-full-version': '"136.0.7103.114"',
    'sec-ch-ua-full-version-list': '"Chromium";v="136.0.7103.114", "Google Chrome";v="136.0.7103.114", "Not.A/Brand";v="99.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"19.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36',
    'x-client-data': 'CIm2yQEIorbJAQipncoBCOfvygEIk6HLAQiSo8sBCIWgzQEI/tPOAQiK7c4BCJDxzgEIkPLOAQi88s4BGODizgE=',
    'x-goog-ext-53200201-jspb': '[{"444624357":[617494298720]}]',
    'x-same-domain': '1',
    # 'cookie': 'HSID=AL5aAepmh94qAPFwy; SSID=Ang8brV8y_xhFr80z; APISID=MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e; SAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-1PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-3PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-ENID=25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A; SID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076; __Secure-1PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076; __Secure-3PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076; SEARCH_SAMESITE=CgQIjZ4B; AEC=AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g; NID=524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go; __Secure-1PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; __Secure-3PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; OTZ=8106180_28_28__28_; SIDCC=AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5; __Secure-1PSIDCC=AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx; __Secure-3PSIDCC=AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

params = {
    'rpcids': 'pONvgf',
    'source-path': '/',
    'f.sid': '5429727544357922217',
    'bl': 'boq_apps-edu-classroom-ui_20250521.05_p0',
    'hl': 'vi',
    'soc-app': '1',
    'soc-platform': '1',
    'soc-device': '1',
    '_reqid': '850451',
    'rt': 'c',
}

data = 'f.req=%5B%5B%5B%22pONvgf%22%2C%22%5B%5B3%2Cnull%2C1%2C0%5D%2C%5B%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5Bnull%2C1%5D%2Cnull%2C%5B1%2C1%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5B1%5D%5D%2Cnull%2Cnull%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%5D%2C%5B%5Bnull%2C%5B%5B%5C%22617494298720%5C%22%5D%5D%2C%5B2%2C5%5D%2C%5B2%5D%2Cnull%2C%5B%5B1748624400000%2C1749229200000%5D%5D%5D%5D%5D%22%2Cnull%2C%22generic%22%5D%5D%5D&at=ACSV3vzxjs3eZjqlQT1FKTRf800z%3A1748674850742&'

response = requests.post(
    'https://classroom.google.com/_/ClassroomUi/data/batchexecute',
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %% [markdown]
# # 12B

# %%
import requests

cookies = {
    'HSID': 'AL5aAepmh94qAPFwy',
    'SSID': 'Ang8brV8y_xhFr80z',
    'APISID': 'MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e',
    'SAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-1PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-3PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-ENID': '25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A',
    'SID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076',
    '__Secure-1PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076',
    '__Secure-3PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076',
    'SEARCH_SAMESITE': 'CgQIjZ4B',
    'AEC': 'AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g',
    'NID': '524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go',
    '__Secure-1PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    '__Secure-3PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    'OTZ': '8106180_28_28__28_',
    'SIDCC': 'AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5',
    '__Secure-1PSIDCC': 'AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx',
    '__Secure-3PSIDCC': 'AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7',
    'content-type': 'application/x-www-form-urlencoded;charset=UTF-8',
    'origin': 'https://classroom.google.com',
    'priority': 'u=1, i',
    'referer': 'https://classroom.google.com/',
    'sec-ch-ua': '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-form-factors': '"Desktop"',
    'sec-ch-ua-full-version': '"136.0.7103.114"',
    'sec-ch-ua-full-version-list': '"Chromium";v="136.0.7103.114", "Google Chrome";v="136.0.7103.114", "Not.A/Brand";v="99.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"19.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36',
    'x-client-data': 'CIm2yQEIorbJAQipncoBCOfvygEIk6HLAQiSo8sBCIWgzQEI/tPOAQiK7c4BCJDxzgEIkPLOAQi88s4BGODizgE=',
    'x-goog-ext-53200201-jspb': '[{"444624357":[537640183485]}]',
    'x-same-domain': '1',
    # 'cookie': 'HSID=AL5aAepmh94qAPFwy; SSID=Ang8brV8y_xhFr80z; APISID=MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e; SAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-1PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-3PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-ENID=25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A; SID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076; __Secure-1PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076; __Secure-3PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076; SEARCH_SAMESITE=CgQIjZ4B; AEC=AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g; NID=524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go; __Secure-1PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; __Secure-3PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; OTZ=8106180_28_28__28_; SIDCC=AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5; __Secure-1PSIDCC=AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx; __Secure-3PSIDCC=AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

params = {
    'rpcids': 'pONvgf',
    'source-path': '/',
    'f.sid': '5429727544357922217',
    'bl': 'boq_apps-edu-classroom-ui_20250521.05_p0',
    'hl': 'vi',
    'soc-app': '1',
    'soc-platform': '1',
    'soc-device': '1',
    '_reqid': '950451',
    'rt': 'c',
}

data = 'f.req=%5B%5B%5B%22pONvgf%22%2C%22%5B%5B3%2Cnull%2C1%2C0%5D%2C%5B%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5Bnull%2C1%5D%2Cnull%2C%5B1%2C1%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5B1%5D%5D%2Cnull%2Cnull%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%5D%2C%5B%5Bnull%2C%5B%5B%5C%22537640183485%5C%22%5D%5D%2C%5B2%2C5%5D%2C%5B2%5D%2Cnull%2C%5B%5B1748624400000%2C1749229200000%5D%5D%5D%5D%5D%22%2Cnull%2C%22generic%22%5D%5D%5D&at=ACSV3vzxjs3eZjqlQT1FKTRf800z%3A1748674850742&'

response = requests.post(
    'https://classroom.google.com/_/ClassroomUi/data/batchexecute',
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %% [markdown]
# # 12A2

# %%
import requests

cookies = {
    'HSID': 'AL5aAepmh94qAPFwy',
    'SSID': 'Ang8brV8y_xhFr80z',
    'APISID': 'MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e',
    'SAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-1PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-3PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-ENID': '25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A',
    'SID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076',
    '__Secure-1PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076',
    '__Secure-3PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076',
    'SEARCH_SAMESITE': 'CgQIjZ4B',
    'AEC': 'AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g',
    'NID': '524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go',
    '__Secure-1PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    '__Secure-3PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    'OTZ': '8106180_28_28__28_',
    'SIDCC': 'AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5',
    '__Secure-1PSIDCC': 'AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx',
    '__Secure-3PSIDCC': 'AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7',
    'content-type': 'application/x-www-form-urlencoded;charset=UTF-8',
    'origin': 'https://classroom.google.com',
    'priority': 'u=1, i',
    'referer': 'https://classroom.google.com/',
    'sec-ch-ua': '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-form-factors': '"Desktop"',
    'sec-ch-ua-full-version': '"136.0.7103.114"',
    'sec-ch-ua-full-version-list': '"Chromium";v="136.0.7103.114", "Google Chrome";v="136.0.7103.114", "Not.A/Brand";v="99.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"19.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36',
    'x-client-data': 'CIm2yQEIorbJAQipncoBCOfvygEIk6HLAQiSo8sBCIWgzQEI/tPOAQiK7c4BCJDxzgEIkPLOAQi88s4BGODizgE=',
    'x-goog-ext-53200201-jspb': '[{"444624357":[537640183485]}]',
    'x-same-domain': '1',
    # 'cookie': 'HSID=AL5aAepmh94qAPFwy; SSID=Ang8brV8y_xhFr80z; APISID=MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e; SAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-1PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-3PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-ENID=25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A; SID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076; __Secure-1PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076; __Secure-3PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076; SEARCH_SAMESITE=CgQIjZ4B; AEC=AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g; NID=524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go; __Secure-1PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; __Secure-3PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; OTZ=8106180_28_28__28_; SIDCC=AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5; __Secure-1PSIDCC=AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx; __Secure-3PSIDCC=AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

params = {
    'rpcids': 'pONvgf',
    'source-path': '/',
    'f.sid': '5429727544357922217',
    'bl': 'boq_apps-edu-classroom-ui_20250521.05_p0',
    'hl': 'vi',
    'soc-app': '1',
    'soc-platform': '1',
    'soc-device': '1',
    '_reqid': '950451',
    'rt': 'c',
}

data = 'f.req=%5B%5B%5B%22pONvgf%22%2C%22%5B%5B3%2Cnull%2C1%2C0%5D%2C%5B%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5Bnull%2C1%5D%2Cnull%2C%5B1%2C1%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5B1%5D%5D%2Cnull%2Cnull%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%5D%2C%5B%5Bnull%2C%5B%5B%5C%22537640183485%5C%22%5D%5D%2C%5B2%2C5%5D%2C%5B2%5D%2Cnull%2C%5B%5B1748624400000%2C1749229200000%5D%5D%5D%5D%5D%22%2Cnull%2C%22generic%22%5D%5D%5D&at=ACSV3vzxjs3eZjqlQT1FKTRf800z%3A1748674850742&'

response = requests.post(
    'https://classroom.google.com/_/ClassroomUi/data/batchexecute',
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %% [markdown]
# # 10A

# %%
import requests

cookies = {
    'HSID': 'AL5aAepmh94qAPFwy',
    'SSID': 'Ang8brV8y_xhFr80z',
    'APISID': 'MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e',
    'SAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-1PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-3PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-ENID': '25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A',
    'SID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076',
    '__Secure-1PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076',
    '__Secure-3PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076',
    'SEARCH_SAMESITE': 'CgQIjZ4B',
    'AEC': 'AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g',
    'NID': '524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go',
    '__Secure-1PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    '__Secure-3PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    'OTZ': '8106180_28_28__28_',
    'SIDCC': 'AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5',
    '__Secure-1PSIDCC': 'AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx',
    '__Secure-3PSIDCC': 'AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7',
    'content-type': 'application/x-www-form-urlencoded;charset=UTF-8',
    'origin': 'https://classroom.google.com',
    'priority': 'u=1, i',
    'referer': 'https://classroom.google.com/',
    'sec-ch-ua': '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-form-factors': '"Desktop"',
    'sec-ch-ua-full-version': '"136.0.7103.114"',
    'sec-ch-ua-full-version-list': '"Chromium";v="136.0.7103.114", "Google Chrome";v="136.0.7103.114", "Not.A/Brand";v="99.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"19.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36',
    'x-client-data': 'CIm2yQEIorbJAQipncoBCOfvygEIk6HLAQiSo8sBCIWgzQEI/tPOAQiK7c4BCJDxzgEIkPLOAQi88s4BGODizgE=',
    'x-goog-ext-53200201-jspb': '[{"444624357":[704635940392]}]',
    'x-same-domain': '1',
    # 'cookie': 'HSID=AL5aAepmh94qAPFwy; SSID=Ang8brV8y_xhFr80z; APISID=MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e; SAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-1PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-3PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-ENID=25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A; SID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076; __Secure-1PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076; __Secure-3PSID=g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076; SEARCH_SAMESITE=CgQIjZ4B; AEC=AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g; NID=524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go; __Secure-1PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; __Secure-3PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; OTZ=8106180_28_28__28_; SIDCC=AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5; __Secure-1PSIDCC=AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx; __Secure-3PSIDCC=AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

params = {
    'rpcids': 'pONvgf',
    'source-path': '/',
    'f.sid': '5429727544357922217',
    'bl': 'boq_apps-edu-classroom-ui_20250521.05_p0',
    'hl': 'vi',
    'soc-app': '1',
    'soc-platform': '1',
    'soc-device': '1',
    '_reqid': '450451',
    'rt': 'c',
}

data = 'f.req=%5B%5B%5B%22pONvgf%22%2C%22%5B%5B3%2Cnull%2C1%2C0%5D%2C%5B%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5Bnull%2C1%5D%2Cnull%2C%5B1%2C1%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5B1%5D%5D%2Cnull%2Cnull%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%5D%2C%5B%5Bnull%2C%5B%5B%5C%22704635940392%5C%22%5D%5D%2C%5B2%2C5%5D%2C%5B2%5D%2Cnull%2C%5B%5B1748624400000%2C1749229200000%5D%5D%5D%5D%5D%22%2Cnull%2C%22generic%22%5D%5D%5D&at=ACSV3vzxjs3eZjqlQT1FKTRf800z%3A1748674850742&'

response = requests.post(
    'https://classroom.google.com/_/ClassroomUi/data/batchexecute',
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %% [markdown]
# # 10B

# %%
import requests

cookies = {
    'HSID': 'AL5aAepmh94qAPFwy',
    'SSID': 'Ang8brV8y_xhFr80z',
    'APISID': 'MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e',
    'SAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-1PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-3PAPISID': '2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94',
    '__Secure-ENID': '25.SE=gFLNWhTuZULhgYETGHLvWU8GgUnAyqGpaPeDjxgNPSgP7I1NWwMA_ZmvA-Gg7fOGLCPAcvILBUYSU-2ow80g47TsB_lQgtwrGP-c5kyHg3pzzVHHVFPJSF3QuHMqQp5EAAOqDOGUa5JN03Kxc7TAUR3MJKL63v1-kcHn5kW9Z3nGfOrT8lpvSmtD90JihdQaz3YDJ_l9GUCtzLM2XI08MaRQyPnfqT8aTt0RUwDfaHyZyotdPZnPL-HNwd8yDZn7m1KIWaRoZt1F0K_bhToBA3MaMs3-u-Mhewz8bQ9ovoy-Fw7wWy4FTo_tQ-nOZHrkKETjk7pfBlEIrUb7Q61Hih4MSvlGFjUnsTBYli8UiTSjVNzaRtlucEAQolCF-iw1TL-GyaFf4ODun44qA5Ad92A',
    'SID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338Ub_oztz2MT2nm9rtcfvYbAACgYKAYISARcSFQHGX2MipG7mYUwXxe2dLXcQf97-AxoVAUF8yKpixg79KqS1BN4DoplFods90076',
    '__Secure-1PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338hqgcBwVCwh1U2oGxLrHALQACgYKAWASARcSFQHGX2MixmjgJA1TYh620NOyzFJbgxoVAUF8yKqSI0p0y9e-XNgprEeYii700076',
    '__Secure-3PSID': 'g.a000wgg-1rl0h8KFPh4Q3wIrPJvIeCoVN4_MeO-kJWQBRRyhM338MEGPBZjo5tHUg0w73TBGjAACgYKAdoSARcSFQHGX2MitwyooLoOpG7_Uq2mVU2ceRoVAUF8yKo7xbV24t0WoPGO4Z_RZOW90076',
    'SEARCH_SAMESITE': 'CgQIjZ4B',
    'AEC': 'AVh_V2iicyznQQzGF1Lnz9tnHUt8_-jY0TuvCwoEsC-MeJsoaAlHNK318g',
    'NID': '524=fN82WnBOdRCGZxvmEvntCNW6rBwv5-pMuq_3VID5y9Sb66bae7oxbU4iBGXOiWoHRyMV6JVZ2c7id-mxpto4Z98erRTmkJ4Js7CkLFHaF5jxugoM55bzDDmBJWjhI-ApckMjao-TxaUXNagK6sGkVYdHM4UnCtpa4RZ5_c-p0WwJKDm4IP3xXZ1Il0jKdQ1v_HJLvXSMiicse2qN9cu-3LYpB1cw5t0jrSJbkMWP5HR-EBlWlEbxhWledGNoYt9FhkoLco2TIODa6s_4JW7rw-P8zln9QnxReoKTw6iN1-cn903UK-nxcjH8UDfZdwCUgozfAZZTbG5gA0RNQ7H4dxsaMKABHfAtbOE3rMIOOhYFWAj4T5xJNoPSdjjohJ4s-KJUxqe1RA2o_qmlmvDdsm2PJsPGxH9ha4t32gPhacXYSmv5Zz-qMP-PMyVqi2XjmGKxJksYzAsR4SXWssKGePajL4j7GT5ullz0tiAqq5t8PDpX2lhYPBq3ekcX-K5xVrtchODGe3hEhWkuu6Nj4V9Xs-ecdm5BEgJlNEsdiHzmHsapiQoSDd42Qvc5EWHw-BKMmpwVLor69OS4JE3vafJ5vBiLzJ_Bd59Q3tIkciRW8RMiWf5sDiRW7QEzBB3fUajOGZoQ26F9LKjRD_x078ocATexvniOVVh0NiDyPnuM4jypD2OH_BFukA1IOxPlOlw-_UW2wvxPBkO_4SkCxnnThUs-pjabZ_CP5zh3-CDdsavPdx8hZYR_n3UzohkKFe4uuPstLApyBGD_yISVs7gsq7OoVepr0nIrxANDqNfiyqzdMIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go',
    '__Secure-1PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    '__Secure-3PSIDTS': 'sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA',
    'OTZ': '8106180_28_28__28_',
    'SIDCC': 'AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5',
    '__Secure-1PSIDCC': 'AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx',
    '__Secure-3PSIDCC': 'AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7',
    'content-type': 'application/x-www-form-urlencoded;charset=UTF-8',
    'origin': 'https://classroom.google.com',
    'priority': 'u=1, i',
    'referer': 'https://classroom.google.com/',
    'sec-ch-ua': '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-form-factors': '"Desktop"',
    'sec-ch-ua-full-version': '"136.0.7103.114"',
    'sec-ch-ua-full-version-list': '"Chromium";v="136.0.7103.114", "Google Chrome";v="136.0.7103.114", "Not.A/Brand";v="99.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"19.0.0"',
    'sec-ch-ua-wow64': '?0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36',
    'x-client-data': 'CIm2yQEIorbJAQipncoBCOfvygEIk6HLAQiSo8sBCIWgzQEI/tPOAQiK7c4BCJDxzgEIkPLOAQi88s4BGODizgE=',
    'x-goog-ext-53200201-jspb': '[{"444624357":[701644605578]}]',
    'x-same-domain': '1',
    # 'cookie': 'HSID=AL5aAepmh94qAPFwy; SSID=Ang8brV8y_xhFr80z; APISID=MBmStSI8mpdT91E2/AX-eTrNjECtb4fX4e; SAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure-1PAPISID=2Q15hUJ1TfqrH8Qa/AiUhcthgZenwP8j94; __Secure
MIYKIV_7eCAIBivBcyGoP5Zx6W9Tk5nv8Gw7hJpo0fGPAqfP3Ss5ydmxhajU7vpY6EVcSWKFFPZpkC2hW4t7Gy5XaVYyxMJJwn_iM8Y5HyAO6b2hBwIw3bcUjKO4jpZJa_coy3KP-7mfah8NmrmzcK3l5nufs29qf52O3lLpmmJ5pxCKRrxaJoqC4SyOfsXJTn8Mbl7492h4-DYJ1SSMZDqnkZb30i3Dvic533Oe5XoCkE0Ubzp9bLPA33_8QFEVZiSXq1gUbmdf8cJddcCWIhQ5GYlpwuMhl_Af_ZVWt6KQBLmTVgkD3QGphtDQCo38oyUUiO8nfGoSu31RhLU5WnQ73xtnqcmFL9PXhTUSkTPEHLMZ_3DqGWRi3YpVU0ll_bTypRQIzn8AN4rlUPGBwoJUtbQw2D2OxUjxh1Go; __Secure-1PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; __Secure-3PSIDTS=sidts-CjIB5H03P6ylWK54zVeahX1rcsO8zZj7_HWaUEXpwhPTSjNtvcratnxYJAFxanzWdwiqnxAA; OTZ=8106180_28_28__28_; SIDCC=AKEyXzV3q9_sc2XL4LhtluiabgDHnXBk3hkZUabXsFQJYt9SRxuGsnxb-5Bf37vLyRLCBl_7FGx5; __Secure-1PSIDCC=AKEyXzW2ZAsId9PZyMwij_tCDT63IkIwPubVXAoBG2jQxdLnqGbH7GRr7d7pb5O-Z6u2gjn0JkYx; __Secure-3PSIDCC=AKEyXzVEQXKU-qpWOWmYpC_1odKj8akCthBjnE_mvbt68iI2y0zV2zrdh62mDBVijvztqT5nWw5j',
}

params = {
    'rpcids': 'pONvgf',
    'source-path': '/',
    'f.sid': '5429727544357922217',
    'bl': 'boq_apps-edu-classroom-ui_20250521.05_p0',
    'hl': 'vi',
    'soc-app': '1',
    'soc-platform': '1',
    'soc-device': '1',
    '_reqid': '550451',
    'rt': 'c',
}

data = 'f.req=%5B%5B%5B%22pONvgf%22%2C%22%5B%5B3%2Cnull%2C1%2C0%5D%2C%5B%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5Bnull%2C1%5D%2Cnull%2C%5B1%2C1%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%2C%5B1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2C1%2Cnull%2C%5B1%2C1%5D%2C1%2C0%2Cnull%2C0%2C%5B%5B1%2C1%2C%5B%5D%2C%5Bnull%2C1%5D%5D%2C1%2C1%5D%2Cnull%2Cnull%2Cnull%2C1%5D%2C%5B1%5D%5D%2Cnull%2Cnull%2C%5B%5B1%2C1%2C1%2C1%2C1%2C0%2Cnull%2C%5B1%2C1%2C1%2Cnull%2C1%2C1%2C1%5D%2C1%2C1%2C1%2C1%2C1%2C1%2C%5B1%5D%2Cnull%2Cnull%2Cnull%2C1%2C3%2Cnull%2Cnull%2C1%2C%5B1%5D%2C0%5D%5D%5D%2C%5B%5Bnull%2C%5B%5B%5C%22701644605578%5C%22%5D%5D%2C%5B2%2C5%5D%2C%5B2%5D%2Cnull%2C%5B%5B1748624400000%2C1749229200000%5D%5D%5D%5D%5D%22%2Cnull%2C%22generic%22%5D%5D%5D&at=ACSV3vzxjs3eZjqlQT1FKTRf800z%3A1748674850742&'

response = requests.post(
    'https://classroom.google.com/_/ClassroomUi/data/batchexecute',
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)
